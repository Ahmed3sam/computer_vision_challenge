# %%
import torch
import numpy as np

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is not available.  Training on CPU ...

# %%
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 20
# percentage of training set to use as validation
valid_size = 0.2

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(), # randomly flip and rotate
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

# choose the training and test datasets
train_data = datasets.CIFAR100(r'C:\Users\Ahmed\Desktop\data', train=True,
                              download=True, transform=transform)
test_data = datasets.CIFAR100(r'C:\Users\Ahmed\Desktop\data', train=False,
                             download=True, transform=transform)

# obtain training indices that will be used for validation
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
    num_workers=num_workers)

# specify the image classes
classes = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'
]
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# helper function to un-normalize and display an image
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
# display 20 images
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the CNN architectureclass Net(nn.Module):
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # convolutional layer (sees 32x32x3 image tensor)
        self.conv1 = nn.Conv2d(3, 32, 5, padding=3)
        # Batch Norm Layer
        self.conv1_bn = nn.BatchNorm2d(32)
        # convolutional layer (sees 16x16x32 tensor)
        self.conv2 = nn.Conv2d(32, 64, 5, padding=1)
        # Batch Norm Layer
        self.conv2_bn = nn.BatchNorm2d(64)
        # convolutional layer (sees 8x8x64 tensor)
        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)
        # Batch Norm Layer
        self.conv3_bn = nn.BatchNorm2d(128)
        # convolutional layer (sees 4x4x128 tensor)
        self.conv4 = nn.Conv2d(128, 256, 1, padding=1)
        # Batch Norm Layer
        self.conv4_bn = nn.BatchNorm2d(256)
        # max pooling layer
        self.pool = nn.MaxPool2d(2, 2)
        # linear layer (256 * 2 * 2 -> 500)
        self.fc1 = nn.Linear(256 * 2 * 2, 512)
        # linear layer (500 -> 100)
        self.fc2 = nn.Linear(512, 100)
        # dropout layer (p=0.25)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        # add sequence of convolutional and max pooling layers
        x = self.conv1_bn(self.pool(self.conv1(x)))
        # add dropout layer
        x = self.dropout(x)
        x = self.conv2_bn(self.pool(self.conv2(x)))
        # add dropout layer
        x = self.dropout(x)
        x = self.conv3_bn(self.pool(self.conv3(x)))
        # add dropout layer
        x = self.dropout(x)
        x = self.conv4_bn(self.pool(self.conv4(x)))
        # add dropout layer
        x = self.dropout(x)
        # flatten image input
        x = x.view(-1, 256 * 2 * 2)
        # add dropout layer
        x = self.dropout(x)
        
        # add 1st hidden layer, with relu activation function
        x = F.relu(self.fc1(x))
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = self.fc2(x)
        return x

# create a complete CNN
model = Net()
print(model)

# move tensors to GPU if CUDA is available
if train_on_gpu:
    model.cuda()
# Out:
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(3, 3))
#   (conv1_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (conv2_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#   (conv4_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1024, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=100, bias=True)
#   (dropout): Dropout(p=0.5)
# )

# %%
import torch.optim as optim

# specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()

# specify optimizer
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
# number of epochs to train the model
n_epochs = 100

valid_loss_min = np.Inf # track change in validation loss

for epoch in range(1, n_epochs+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train()
    for data, target in train_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval()
    for data, target in valid_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
    
    # calculate average losses
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
        
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model_cifar_100.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 3.512134 	Validation Loss: 0.853652
# Validation loss decreased (inf --> 0.853652).  Saving model ...
# Epoch: 2 	Training Loss: 3.245463 	Validation Loss: 0.799719
# Validation loss decreased (0.853652 --> 0.799719).  Saving model ...
# Epoch: 3 	Training Loss: 3.117082 	Validation Loss: 0.785164
# Validation loss decreased (0.799719 --> 0.785164).  Saving model ...
# Epoch: 4 	Training Loss: 3.045677 	Validation Loss: 0.765162
# Validation loss decreased (0.785164 --> 0.765162).  Saving model ...
# Epoch: 5 	Training Loss: 2.989654 	Validation Loss: 0.758086
# Validation loss decreased (0.765162 --> 0.758086).  Saving model ...
# Epoch: 6 	Training Loss: 2.948738 	Validation Loss: 0.749684
# Validation loss decreased (0.758086 --> 0.749684).  Saving model ...
# Epoch: 7 	Training Loss: 2.915808 	Validation Loss: 0.728237
# Validation loss decreased (0.749684 --> 0.728237).  Saving model ...
# Epoch: 8 	Training Loss: 2.872700 	Validation Loss: 0.721897
# Validation loss decreased (0.728237 --> 0.721897).  Saving model ...
# Epoch: 9 	Training Loss: 2.851290 	Validation Loss: 0.694011
# Validation loss decreased (0.721897 --> 0.694011).  Saving model ...
# Epoch: 10 	Training Loss: 2.826840 	Validation Loss: 0.695467
# Epoch: 11 	Training Loss: 2.808524 	Validation Loss: 0.695419
# Epoch: 12 	Training Loss: 2.777853 	Validation Loss: 0.691340
# Validation loss decreased (0.694011 --> 0.691340).  Saving model ...
# Epoch: 13 	Training Loss: 2.768142 	Validation Loss: 0.676103
# Validation loss decreased (0.691340 --> 0.676103).  Saving model ...
# Epoch: 14 	Training Loss: 2.742456 	Validation Loss: 0.674421
# Validation loss decreased (0.676103 --> 0.674421).  Saving model ...
# Epoch: 15 	Training Loss: 2.720850 	Validation Loss: 0.674853
# Epoch: 16 	Training Loss: 2.709927 	Validation Loss: 0.664323
# Validation loss decreased (0.674421 --> 0.664323).  Saving model ...
# Epoch: 17 	Training Loss: 2.695476 	Validation Loss: 0.641125
# Validation loss decreased (0.664323 --> 0.641125).  Saving model ...
# Epoch: 18 	Training Loss: 2.674458 	Validation Loss: 0.663984
# Epoch: 19 	Training Loss: 2.665679 	Validation Loss: 0.633067
# Validation loss decreased (0.641125 --> 0.633067).  Saving model ...
# Epoch: 20 	Training Loss: 2.650180 	Validation Loss: 0.641591
# Epoch: 21 	Training Loss: 2.632966 	Validation Loss: 0.625674
# Validation loss decreased (0.633067 --> 0.625674).  Saving model ...
# Epoch: 22 	Training Loss: 2.621262 	Validation Loss: 0.629419
# Epoch: 23 	Training Loss: 2.614262 	Validation Loss: 0.614695
# Validation loss decreased (0.625674 --> 0.614695).  Saving model ...
# Epoch: 24 	Training Loss: 2.592121 	Validation Loss: 0.609532
# Validation loss decreased (0.614695 --> 0.609532).  Saving model ...
# Epoch: 25 	Training Loss: 2.586167 	Validation Loss: 0.624410
# Epoch: 26 	Training Loss: 2.567556 	Validation Loss: 0.614055
# Epoch: 27 	Training Loss: 2.561552 	Validation Loss: 0.611502
# Epoch: 28 	Training Loss: 2.555323 	Validation Loss: 0.616892
# Epoch: 29 	Training Loss: 2.545253 	Validation Loss: 0.594310
# Validation loss decreased (0.609532 --> 0.594310).  Saving model ...
# Epoch: 30 	Training Loss: 2.537127 	Validation Loss: 0.596403
# Epoch: 31 	Training Loss: 2.530520 	Validation Loss: 0.596223
# Epoch: 32 	Training Loss: 2.516005 	Validation Loss: 0.596565
# Epoch: 33 	Training Loss: 2.512855 	Validation Loss: 0.604282
# Epoch: 34 	Training Loss: 2.493307 	Validation Loss: 0.585681
# Validation loss decreased (0.594310 --> 0.585681).  Saving model ...
# Epoch: 35 	Training Loss: 2.492597 	Validation Loss: 0.580957
# Validation loss decreased (0.585681 --> 0.580957).  Saving model ...
# Epoch: 36 	Training Loss: 2.485182 	Validation Loss: 0.593954
# Epoch: 37 	Training Loss: 2.480083 	Validation Loss: 0.586941
# Epoch: 38 	Training Loss: 2.473669 	Validation Loss: 0.583465
# Epoch: 39 	Training Loss: 2.465799 	Validation Loss: 0.579531
# Validation loss decreased (0.580957 --> 0.579531).  Saving model ...
# Epoch: 40 	Training Loss: 2.467175 	Validation Loss: 0.579251
# Validation loss decreased (0.579531 --> 0.579251).  Saving model ...
# Epoch: 41 	Training Loss: 2.458488 	Validation Loss: 0.573836
# Validation loss decreased (0.579251 --> 0.573836).  Saving model ...
# Epoch: 42 	Training Loss: 2.443677 	Validation Loss: 0.581128
# Epoch: 43 	Training Loss: 2.446693 	Validation Loss: 0.570205
# Validation loss decreased (0.573836 --> 0.570205).  Saving model ...
# Epoch: 44 	Training Loss: 2.442572 	Validation Loss: 0.581473
# Epoch: 45 	Training Loss: 2.430451 	Validation Loss: 0.568310
# Validation loss decreased (0.570205 --> 0.568310).  Saving model ...
# Epoch: 46 	Training Loss: 2.425739 	Validation Loss: 0.567563
# Validation loss decreased (0.568310 --> 0.567563).  Saving model ...
# Epoch: 47 	Training Loss: 2.422936 	Validation Loss: 0.565363
# Validation loss decreased (0.567563 --> 0.565363).  Saving model ...
# Epoch: 48 	Training Loss: 2.409654 	Validation Loss: 0.562748
# Validation loss decreased (0.565363 --> 0.562748).  Saving model ...
# Epoch: 49 	Training Loss: 2.416564 	Validation Loss: 0.570669
# Epoch: 50 	Training Loss: 2.407473 	Validation Loss: 0.553594
# Validation loss decreased (0.562748 --> 0.553594).  Saving model ...
# Epoch: 51 	Training Loss: 2.407333 	Validation Loss: 0.565571
# Epoch: 52 	Training Loss: 2.401078 	Validation Loss: 0.552927
# Validation loss decreased (0.553594 --> 0.552927).  Saving model ...
# Epoch: 53 	Training Loss: 2.404698 	Validation Loss: 0.564593
# Epoch: 54 	Training Loss: 2.391881 	Validation Loss: 0.558415
# Epoch: 55 	Training Loss: 2.389820 	Validation Loss: 0.550557
# Validation loss decreased (0.552927 --> 0.550557).  Saving model ...
# Epoch: 56 	Training Loss: 2.389147 	Validation Loss: 0.552819
# Epoch: 57 	Training Loss: 2.387890 	Validation Loss: 0.553231
# Epoch: 58 	Training Loss: 2.380603 	Validation Loss: 0.552041
# Epoch: 59 	Training Loss: 2.377813 	Validation Loss: 0.549086
# Validation loss decreased (0.550557 --> 0.549086).  Saving model ...
# Epoch: 60 	Training Loss: 2.374485 	Validation Loss: 0.540353
# Validation loss decreased (0.549086 --> 0.540353).  Saving model ...
# Epoch: 61 	Training Loss: 2.366164 	Validation Loss: 0.548177
# Epoch: 62 	Training Loss: 2.366903 	Validation Loss: 0.549081
# Epoch: 63 	Training Loss: 2.363894 	Validation Loss: 0.554818
# Epoch: 64 	Training Loss: 2.362977 	Validation Loss: 0.554545
# Epoch: 65 	Training Loss: 2.351123 	Validation Loss: 0.549973
# Epoch: 66 	Training Loss: 2.355108 	Validation Loss: 0.542070
# Epoch: 67 	Training Loss: 2.351157 	Validation Loss: 0.552253
# Epoch: 68 	Training Loss: 2.350811 	Validation Loss: 0.539811
# Validation loss decreased (0.540353 --> 0.539811).  Saving model ...
# Epoch: 69 	Training Loss: 2.343404 	Validation Loss: 0.536293
# Validation loss decreased (0.539811 --> 0.536293).  Saving model ...
# Epoch: 70 	Training Loss: 2.344950 	Validation Loss: 0.534548
# Validation loss decreased (0.536293 --> 0.534548).  Saving model ...
# Epoch: 71 	Training Loss: 2.343284 	Validation Loss: 0.528335
# Validation loss decreased (0.534548 --> 0.528335).  Saving model ...
# Epoch: 72 	Training Loss: 2.340826 	Validation Loss: 0.529816
# Epoch: 73 	Training Loss: 2.336802 	Validation Loss: 0.543233
# Epoch: 74 	Training Loss: 2.332014 	Validation Loss: 0.528885
# Epoch: 75 	Training Loss: 2.331087 	Validation Loss: 0.528287
# Validation loss decreased (0.528335 --> 0.528287).  Saving model ...
# Epoch: 76 	Training Loss: 2.328762 	Validation Loss: 0.525828
# Validation loss decreased (0.528287 --> 0.525828).  Saving model ...
# Epoch: 77 	Training Loss: 2.325360 	Validation Loss: 0.530229
# Epoch: 78 	Training Loss: 2.330604 	Validation Loss: 0.537773
# Epoch: 79 	Training Loss: 2.320415 	Validation Loss: 0.528486
# Epoch: 80 	Training Loss: 2.317750 	Validation Loss: 0.538218
# Epoch: 81 	Training Loss: 2.317235 	Validation Loss: 0.525287
# Validation loss decreased (0.525828 --> 0.525287).  Saving model ...
# Epoch: 82 	Training Loss: 2.320777 	Validation Loss: 0.533872
# Epoch: 83 	Training Loss: 2.320314 	Validation Loss: 0.537142
# Epoch: 84 	Training Loss: 2.310526 	Validation Loss: 0.531076
# Epoch: 85 	Training Loss: 2.308394 	Validation Loss: 0.527844
# Epoch: 86 	Training Loss: 2.309931 	Validation Loss: 0.536009
# Epoch: 87 	Training Loss: 2.303090 	Validation Loss: 0.536924
# Epoch: 88 	Training Loss: 2.301729 	Validation Loss: 0.523409
# Validation loss decreased (0.525287 --> 0.523409).  Saving model ...
# Epoch: 89 	Training Loss: 2.295827 	Validation Loss: 0.531260
# Epoch: 90 	Training Loss: 2.301562 	Validation Loss: 0.527446
# Epoch: 91 	Training Loss: 2.303176 	Validation Loss: 0.527181
# Epoch: 92 	Training Loss: 2.296818 	Validation Loss: 0.525286
# Epoch: 93 	Training Loss: 2.295019 	Validation Loss: 0.529209
# Epoch: 94 	Training Loss: 2.288477 	Validation Loss: 0.512217
# Validation loss decreased (0.523409 --> 0.512217).  Saving model ...
# Epoch: 95 	Training Loss: 2.290610 	Validation Loss: 0.522618
# Epoch: 96 	Training Loss: 2.291896 	Validation Loss: 0.529860
# Epoch: 97 	Training Loss: 2.285128 	Validation Loss: 0.530260
# Epoch: 98 	Training Loss: 2.285722 	Validation Loss: 0.520538
# Epoch: 99 	Training Loss: 2.283131 	Validation Loss: 0.515918
# Epoch: 100 	Training Loss: 2.288603 	Validation Loss: 0.528941

# %%
model.load_state_dict(torch.load('model_cifar_100.pt'))

# %%
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(100))
class_total = list(0. for i in range(100))

model.eval()
# iterate over test data
for batch_idx, (data, target) in enumerate(test_loader):
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(100):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 2.549937
#
# Test Accuracy of apple: 69% (69/100)
# Test Accuracy of aquarium_fish: 33% (33/100)
# Test Accuracy of  baby: 20% (20/100)
# Test Accuracy of  bear:  9% ( 9/100)
# Test Accuracy of beaver: 20% (20/100)
# Test Accuracy of   bed: 25% (25/100)
# Test Accuracy of   bee: 32% (32/100)
# Test Accuracy of beetle: 36% (36/100)
# Test Accuracy of bicycle: 45% (45/100)
# Test Accuracy of bottle: 34% (34/100)
# Test Accuracy of  bowl: 11% (11/100)
# Test Accuracy of   boy:  8% ( 8/100)
# Test Accuracy of bridge: 34% (34/100)
# Test Accuracy of   bus: 14% (14/100)
# Test Accuracy of butterfly: 18% (18/100)
# Test Accuracy of camel: 12% (12/100)
# Test Accuracy of   can: 26% (26/100)
# Test Accuracy of castle: 62% (62/100)
# Test Accuracy of caterpillar: 20% (20/100)
# Test Accuracy of cattle: 15% (15/100)
# Test Accuracy of chair: 56% (56/100)
# Test Accuracy of chimpanzee: 65% (65/100)
# Test Accuracy of clock: 14% (14/100)
# Test Accuracy of cloud: 70% (70/100)
# Test Accuracy of cockroach: 65% (65/100)
# Test Accuracy of couch: 22% (22/100)
# Test Accuracy of  crab: 29% (29/100)
# Test Accuracy of crocodile: 41% (41/100)
# Test Accuracy of   cup: 42% (42/100)
# Test Accuracy of dinosaur: 23% (23/100)
# Test Accuracy of dolphin: 61% (61/100)
# Test Accuracy of elephant: 47% (47/100)
# Test Accuracy of flatfish: 17% (17/100)
# Test Accuracy of forest: 49% (49/100)
# Test Accuracy of   fox: 15% (15/100)
# Test Accuracy of  girl: 20% (20/100)
# Test Accuracy of hamster: 29% (29/100)
# Test Accuracy of house: 38% (38/100)
# Test Accuracy of kangaroo: 23% (23/100)
# Test Accuracy of keyboard: 62% (62/100)
# Test Accuracy of  lamp: 17% (17/100)
# Test Accuracy of lawn_mower: 53% (53/100)
# Test Accuracy of leopard: 54% (54/100)
# Test Accuracy of  lion: 64% (64/100)
# Test Accuracy of lizard: 16% (16/100)
# Test Accuracy of lobster: 21% (21/100)
# Test Accuracy of   man: 14% (14/100)
# Test Accuracy of maple_tree: 43% (43/100)
# Test Accuracy of motorcycle: 65% (65/100)
# Test Accuracy of mountain: 64% (64/100)
# Test Accuracy of mouse:  5% ( 5/100)
# Test Accuracy of mushroom: 17% (17/100)
# Test Accuracy of oak_tree: 80% (80/100)
# Test Accuracy of orange: 62% (62/100)
# Test Accuracy of orchid: 40% (40/100)
# Test Accuracy of otter:  2% ( 2/100)
# Test Accuracy of palm_tree: 38% (38/100)
# Test Accuracy of  pear: 26% (26/100)
# Test Accuracy of pickup_truck: 22% (22/100)
# Test Accuracy of pine_tree: 24% (24/100)
# Test Accuracy of plain: 74% (74/100)
# Test Accuracy of plate: 54% (54/100)
# Test Accuracy of poppy: 22% (22/100)
# Test Accuracy of porcupine: 44% (44/100)
# Test Accuracy of possum:  5% ( 5/100)
# Test Accuracy of rabbit:  8% ( 8/100)
# Test Accuracy of raccoon: 30% (30/100)
# Test Accuracy of   ray: 31% (31/100)
# Test Accuracy of  road: 67% (67/100)
# Test Accuracy of rocket: 43% (43/100)
# Test Accuracy of  rose: 54% (54/100)
# Test Accuracy of   sea: 55% (55/100)
# Test Accuracy of  seal:  4% ( 4/100)
# Test Accuracy of shark: 19% (19/100)
# Test Accuracy of shrew: 32% (32/100)
# Test Accuracy of skunk: 55% (55/100)
# Test Accuracy of skyscraper: 61% (61/100)
# Test Accuracy of snail:  4% ( 4/100)
# Test Accuracy of snake: 23% (23/100)
# Test Accuracy of spider: 41% (41/100)
# Test Accuracy of squirrel: 15% (15/100)
# Test Accuracy of streetcar: 49% (49/100)
# Test Accuracy of sunflower: 73% (73/100)
# Test Accuracy of sweet_pepper: 10% (10/100)
# Test Accuracy of table: 19% (19/100)
# Test Accuracy of  tank: 66% (66/100)
# Test Accuracy of telephone: 33% (33/100)
# Test Accuracy of television: 44% (44/100)
# Test Accuracy of tiger: 33% (33/100)
# Test Accuracy of tractor: 34% (34/100)
# Test Accuracy of train: 17% (17/100)
# Test Accuracy of trout: 47% (47/100)
# Test Accuracy of tulip: 10% (10/100)
# Test Accuracy of turtle:  8% ( 8/100)
# Test Accuracy of wardrobe: 82% (82/100)
# Test Accuracy of whale: 31% (31/100)
# Test Accuracy of willow_tree: 48% (48/100)
# Test Accuracy of  wolf: 53% (53/100)
# Test Accuracy of woman:  7% ( 7/100)
# Test Accuracy of  worm: 19% (19/100)
#
# Test Accuracy (Overall): 34% (3482/10000)

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images.numpy()

# move model inputs to cuda, if GPU available
if train_on_gpu:
    images = images.cuda()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title("{} ({})".format(classes[preds[idx]], classes[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))
